# %%
from alab_control.robot_arm_ur5e import URRobotDashboard

robot_arm = URRobotDashboard("192.168.1.24")

slots = [3, 4, 5], #6, 7, 8]

for slot in slots:
    new_slot = slot - 2

    robot_arm.run_program(
        f"auto_program/pick_crucible_furnace_rack/pick_crucible_furnace_rack_{slot}.auto.urp"
    )
    robot_arm.run_program(
        f"auto_program/place_crucible_furnace_rack/place_crucible_furnace_rack_{new_slot}.auto.urp"
    )
# Out:
# c:\Users\Ceder-Alab\project\.venv\Lib\site-packages\paramiko\pkey.py:82: CryptographyDeprecationWarning: TripleDES has been moved to cryptography.hazmat.decrepit.ciphers.algorithms.TripleDES and will be removed from cryptography.hazmat.primitives.ciphers.algorithms in 48.0.0.
#   "cipher": algorithms.TripleDES,
# c:\Users\Ceder-Alab\project\.venv\Lib\site-packages\paramiko\transport.py:219: CryptographyDeprecationWarning: Blowfish has been moved to cryptography.hazmat.decrepit.ciphers.algorithms.Blowfish and will be removed from cryptography.hazmat.primitives.ciphers.algorithms in 45.0.0.
#   "class": algorithms.Blowfish,
# c:\Users\Ceder-Alab\project\.venv\Lib\site-packages\paramiko\transport.py:243: CryptographyDeprecationWarning: TripleDES has been moved to cryptography.hazmat.decrepit.ciphers.algorithms.TripleDES and will be removed from cryptography.hazmat.primitives.ciphers.algorithms in 48.0.0.
#   "class": algorithms.TripleDES,
