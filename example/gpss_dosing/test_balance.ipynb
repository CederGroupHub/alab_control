# %%
from alab_control.mt_auto_balance.auto_balance import MTAutoBalance
balance = MTAutoBalance("http://192.168.1.91:81")


for i in range(1):
    print(f"Iteration {i}")
    print("Opening and closing the doors")
    balance.open_door("LeftOuter")
    balance.close_door("LeftOuter")
    # balance.open_door("RightOuter")
    # balance.close_door("RightOuter")
    print("Dosing")
    # result = balance.automatic_dosing(
    #     target_value_g=0.01,
    #     lower_tolerance_percent=10,
    #     upper_tolerance_percent=10,
    # )
    # print(result)
    # print(balance.get_weight())
    print("--------------------------------")
# Out:
# Iteration 0
# Opening and closing the doors
# Dosing
# --------------------------------
