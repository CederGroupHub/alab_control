# %%
from alab_control.gripper_shaker.gripper_shaker import GripperShaker


gripper_shaker = GripperShaker("192.168.1.58", com_port="COM4")

# %%
gripper_shaker.reset_gripper()

# %%
gripper_shaker.get_state()
# Out:
# {'state': <MotorState.STOPPED: 'stopped'>}
