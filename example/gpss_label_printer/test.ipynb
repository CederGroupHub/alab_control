# %%
from alab_control.dymo_labelwriter.dymo_labelwriter import DYMOLabelWriter

# %%
dymo = DYMOLabelWriter("192.168.1.54", "aaa")

# %%
from bson import ObjectId
90
dymo.print_label(ObjectId(), "12345689900988909887890", 3, 4, True)
# Out:
# <PIL.Image.Image image mode=RGBA size=300x300>
