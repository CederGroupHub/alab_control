# %%
from alab_control.dymo_labelwriter.dymo_labelwriter import DYMOLabelWriter

# %%
from bson import ObjectId

dymo = DYMOLabelWriter("Dymo LabelWriter Wireless", sumatra_pdf_path=r"C:\Users\Ceder-Alab\AppData\Local\SumatraPDF\SumatraPDF.exe")

# Print all labels with status "in_use" 
# (sample_id, sample_name, level, row)

# Level 1
dymo.print_label(ObjectId("69e82e71f4ac2c48fd960a9a"), "Li2Cr0p6777Cl4_042126", 2, 3, False)
# dymo.print_label(ObjectId("69603efc647ef7f0e789d5c6"), "Li1p6Mn0p1Fe0p6In0p2Hf0p1Cl4_010826", 1, 4, False)
# dymo.print_label(ObjectId("69603efd647ef7f0e789d5d6"), "Li2MgCl4_010826", 1, 5, False)

# # Level 2
# dymo.print_label(ObjectId("69603efe647ef7f0e789d5e1"), "Li1p6Fe0p8Co0p4Cl4_010826", 2, 2, False)
# dymo.print_label(ObjectId("69603eff647ef7f0e789d5f2"), "Li1p85Fe0p85Bi0p15Cl4_010826", 2, 4, False)

# # Level 6
# dymo.print_label(ObjectId("6960367f647ef7f0e789d544"), "Li1p5Mn0p8V0p3Cl3F_010826", 6, 4, False)
# dymo.print_label(ObjectId("6960367f647ef7f0e789d545"), "Li1p8Mn1p1Cl3F_010826", 6, 5, False)

# # Level 7
# dymo.print_label(ObjectId("6960367f647ef7f0e789d546"), "Li1p5Mn1p1Cl3F_010826", 7, 1, False)
# dymo.print_label(ObjectId("69603bc2647ef7f0e789d58d"), "Li1p64Mn0p78Nb0p07V0p15Cl4_010826", 7, 2, False)
# dymo.print_label(ObjectId("69603bc2647ef7f0e789d58c"), "Li1p65Mn0p89Hf0p03V0p15Cl4_010826", 7, 3, False)
# dymo.print_label(ObjectId("69603efb647ef7f0e789d5bb"), "Li1p9Cr0p525Mn0p525Cl4_010826", 7, 4, False)
# dymo.print_label(ObjectId("69603efc647ef7f0e789d5c5"), "Li1p5Fe0p3In0p3Mn0p3Mg0p2Cl4_010826", 7, 5, False)
