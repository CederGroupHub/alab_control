# %%
from alab_control.dh_robotic_gripper.dh_robotic_gripper import GripperController

# %%
controller = GripperController("COM8")

# %%
controller.check_initialization()
# Out:
# <InitializationStatus.INITIALIZED: 1>

# %%
controller.close()
